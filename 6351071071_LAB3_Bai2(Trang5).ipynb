# %% [markdown]
# <a href="https://colab.research.google.com/github/tuilatoan15/6351071071_Lab3/blob/main/6351071071_LAB3_Bai2(Trang5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Câu a

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist

# Đọc dữ liệu MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

print("Đã load xong bộ dữ liệu MNIST!")
# Out:
# Nguyễn Hữu Toàn – 6351071071
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Đã load xong bộ dữ liệu MNIST!

# %% [markdown]
# #Câu b

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

print("Kích thước tập train:", train_images.shape, train_labels.shape)
print("Kích thước tập test:", test_images.shape, test_labels.shape)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Kích thước tập train: (60000, 28, 28) (60000,)
# Kích thước tập test: (10000, 28, 28) (10000,)

# %% [markdown]
# #Câu c

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Chuẩn hóa pixel về [0, 1]
train_images = train_images / 255.0
test_images = test_images / 255.0

print("Đã chuẩn hóa giá trị pixel về [0,1]")
print("Giá trị pixel sau chuẩn hóa (ví dụ phần tử đầu tiên):", train_images[0][0][0])
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Đã chuẩn hóa giá trị pixel về [0,1]
# Giá trị pixel sau chuẩn hóa (ví dụ phần tử đầu tiên): 0.0

# %% [markdown]
# #Câu d

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu như các bước trước
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train thành train + validation (tỉ lệ 80% - 20%)
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# In shape của từng tập
print("Kích thước tập train:", train_images.shape, train_labels.shape)
print("Kích thước tập validation:", validation_images.shape, validation_labels.shape)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Kích thước tập train: (48000, 28, 28) (48000,)
# Kích thước tập validation: (12000, 28, 28) (12000,)

# %% [markdown]
# #Câu e

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

print("Mô hình Neural Network đã được xây dựng xong!")
model.summary()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Mô hình Neural Network đã được xây dựng xong!
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# #Câu f

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',                       # tối ưu Adam
    loss='sparse_categorical_crossentropy', # loss cho phân lớp nhiều lớp với nhãn nguyên
    metrics=['accuracy']                     # theo dõi accuracy
)

print("Mô hình đã được biên dịch xong!")
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Mô hình đã được biên dịch xong!

# %% [markdown]
# #Câu g

# %%
print("Nguyễn Hữu Toàn – 6351071071")

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
history = model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

print("Mô hình đã được huấn luyện xong!")
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8492 - loss: 0.5219 - val_accuracy: 0.9539 - val_loss: 0.1600
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9519 - loss: 0.1632 - val_accuracy: 0.9631 - val_loss: 0.1215
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9636 - loss: 0.1210 - val_accuracy: 0.9707 - val_loss: 0.1024
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9718 - loss: 0.0930 - val_accuracy: 0.9718 - val_loss: 0.0977
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9745 - loss: 0.0807 - val_accuracy: 0.9743 - val_loss: 0.0856
# Mô hình đã được huấn luyện xong!

# %% [markdown]
# #Câu h

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
history = model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Vẽ biểu đồ accuracy
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy sau mỗi epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Vẽ biểu đồ loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss sau mỗi epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8481 - loss: 0.5254 - val_accuracy: 0.9501 - val_loss: 0.1689
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9492 - loss: 0.1741 - val_accuracy: 0.9649 - val_loss: 0.1219
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9637 - loss: 0.1207 - val_accuracy: 0.9707 - val_loss: 0.0976
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9718 - loss: 0.0932 - val_accuracy: 0.9730 - val_loss: 0.0917
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9768 - loss: 0.0728 - val_accuracy: 0.9743 - val_loss: 0.0892

# %% [markdown]
# #Câu i

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
history = model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Dự đoán xác suất cho tập test
pred_probs = model.predict(test_images)

# Chọn lớp có xác suất lớn nhất cho mỗi mẫu
pred_labels = np.argmax(pred_probs, axis=1)

# In kết quả dự đoán 10 mẫu đầu tiên
print("Dự đoán 10 mẫu đầu tiên:", pred_labels[:10])
print("Nhãn thực tế 10 mẫu đầu tiên:", test_labels[:10])
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8452 - loss: 0.5329 - val_accuracy: 0.9531 - val_loss: 0.1668
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9508 - loss: 0.1667 - val_accuracy: 0.9637 - val_loss: 0.1214
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9634 - loss: 0.1203 - val_accuracy: 0.9691 - val_loss: 0.1013
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9701 - loss: 0.0956 - val_accuracy: 0.9733 - val_loss: 0.0870
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9759 - loss: 0.0779 - val_accuracy: 0.9761 - val_loss: 0.0822
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Dự đoán 10 mẫu đầu tiên: [7 2 1 0 4 1 4 9 5 9]
# Nhãn thực tế 10 mẫu đầu tiên: [7 2 1 0 4 1 4 9 5 9]

# %% [markdown]
# #Câu j

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Dự đoán nhãn trên tập test
pred_labels = np.argmax(model.predict(test_images), axis=1)

# Tính Accuracy
accuracy = accuracy_score(test_labels, pred_labels)
print("Accuracy trên tập test:", accuracy)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.8477 - loss: 0.5256 - val_accuracy: 0.9533 - val_loss: 0.1636
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9517 - loss: 0.1621 - val_accuracy: 0.9662 - val_loss: 0.1164
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9641 - loss: 0.1171 - val_accuracy: 0.9707 - val_loss: 0.0985
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9695 - loss: 0.0993 - val_accuracy: 0.9740 - val_loss: 0.0897
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9757 - loss: 0.0790 - val_accuracy: 0.9753 - val_loss: 0.0813
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy trên tập test: 0.9751

# %% [markdown]
# #Câu k

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Dự đoán nhãn trên tập test
pred_labels = np.argmax(model.predict(test_images), axis=1)

# Tính Precision, Recall, F1-score
report = classification_report(test_labels, pred_labels, digits=4)
print("Classification Report:\n", report)
# Out:
# Nguyễn Hữu Toàn – 6351071071
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8452 - loss: 0.5301 - val_accuracy: 0.9534 - val_loss: 0.1556
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9525 - loss: 0.1684 - val_accuracy: 0.9642 - val_loss: 0.1144
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9634 - loss: 0.1223 - val_accuracy: 0.9704 - val_loss: 0.0967
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9708 - loss: 0.0955 - val_accuracy: 0.9718 - val_loss: 0.0924
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9773 - loss: 0.0771 - val_accuracy: 0.9751 - val_loss: 0.0836
# ...

# %% [markdown]
# #Câu l

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Dự đoán nhãn trên tập test
pred_labels = np.argmax(model.predict(test_images), axis=1)

# Tính confusion matrix
cm = confusion_matrix(test_labels, pred_labels)

# Vẽ heatmap
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8462 - loss: 0.5312 - val_accuracy: 0.9536 - val_loss: 0.1647
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9504 - loss: 0.1708 - val_accuracy: 0.9659 - val_loss: 0.1191
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9639 - loss: 0.1224 - val_accuracy: 0.9703 - val_loss: 0.0982
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9708 - loss: 0.0944 - val_accuracy: 0.9747 - val_loss: 0.0874
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9736 - loss: 0.0820 - val_accuracy: 0.9732 - val_loss: 0.0868
# ...

# %% [markdown]
# #Câu m

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Hiển thị và dự đoán 5 ảnh đầu tiên
for i in range(5):
    img = np.expand_dims(test_images[i], axis=0)  # Chuyển sang 1 mẫu 1D
    pred = np.argmax(model.predict(img), axis=1)[0]

    plt.imshow(test_images[i], cmap='gray')
    plt.title(f'Predicted: {pred}, True: {test_labels[i]}')
    plt.axis('off')
    plt.show()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8473 - loss: 0.5278 - val_accuracy: 0.9544 - val_loss: 0.1576
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9518 - loss: 0.1645 - val_accuracy: 0.9639 - val_loss: 0.1185
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9632 - loss: 0.1258 - val_accuracy: 0.9683 - val_loss: 0.1017
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9691 - loss: 0.1007 - val_accuracy: 0.9746 - val_loss: 0.0877
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9767 - loss: 0.0774 - val_accuracy: 0.9753 - val_loss: 0.0797
# ...

# %% [markdown]
# #Câu n

# %%
print("Nguyễn Hữu Toàn – 6351071071")

import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split

# Đọc và chuẩn hóa dữ liệu
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# Chia train - validation
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Xây dựng mô hình
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Biên dịch mô hình
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Huấn luyện mô hình
model.fit(
    train_images, train_labels,
    validation_data=(validation_images, validation_labels),
    epochs=5,
    batch_size=32,
    verbose=1
)

# Dự đoán nhãn trên tập test
pred_labels = np.argmax(model.predict(test_images), axis=1)

# Tìm các mẫu phân lớp sai
wrong_indices = np.where(pred_labels != test_labels)[0]

print("Số mẫu phân lớp sai:", len(wrong_indices))

# Hiển thị 5 mẫu phân lớp sai đầu tiên
for idx in wrong_indices[:5]:
    plt.imshow(test_images[idx], cmap='gray')
    plt.title(f'Predicted: {pred_labels[idx]}, True: {test_labels[idx]}')
    plt.axis('off')
    plt.show()
# Out:
# Nguyễn Hữu Toàn – 6351071071
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8469 - loss: 0.5249 - val_accuracy: 0.9522 - val_loss: 0.1643
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9515 - loss: 0.1649 - val_accuracy: 0.9647 - val_loss: 0.1205
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9658 - loss: 0.1149 - val_accuracy: 0.9703 - val_loss: 0.1011
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9701 - loss: 0.0957 - val_accuracy: 0.9730 - val_loss: 0.0946
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9760 - loss: 0.0780 - val_accuracy: 0.9750 - val_loss: 0.0819
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Số mẫu phân lớp sai: 243
